# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
df = pd.read_csv('loan.csv')
df.head(20)
# Out:
#     age  gender  occupation education_level marital_status  income  \
# 0    32    Male    Engineer      Bachelor's        Married   85000
# 1    45  Female     Teacher        Master's         Single   62000
# 2    28    Male     Student     High School         Single   25000
# 3    51  Female     Manager      Bachelor's        Married  105000
# 4    36    Male  Accountant      Bachelor's        Married   75000
# 5    24  Female       Nurse     Associate's         Single   48000
# 6    42    Male      Lawyer        Doctoral        Married  120000
# 7    29  Female      Artist      Bachelor's         Single   38000
# 8    37    Male          IT        Master's        Married   92000
# 9    48  Female      Doctor        Doctoral        Married  180000
# 10   55    Male  Consultant        Master's        Married  110000
# 11   31  Female     Analyst      Bachelor's         Single   68000
# 12   26    Male    Salesman     High School         Single   42000
# 13   39  Female   Marketing      Bachelor's        Married   78000
# 14   44    Male   Architect        Master's        Married   95000
# 15   27  Female    Designer      Bachelor's         Single   52000
# 16   34    Male    Engineer      Bachelor's        Married   88000
# 17   41  Female  Pharmacist        Doctoral        Married  125000
# 18   30    Male  Researcher        Master's         Single   72000
# 19   53  Female   Professor        Doctoral        Married   98000
#
#     credit_score loan_status
# 0            720    Approved
# 1            680    Approved
# 2            590      Denied
# 3            780    Approved
# 4            710    Approved
# 5            640      Denied
# 6            790    Approved
# 7            620      Denied
# 8            750    Approved
# 9            820    Approved
# 10           770    Approved
# 11           690    Approved
# 12           610      Denied
# 13           730    Approved
# 14           760    Approved
# 15           650      Denied
# 16           740    Approved
# 17           800    Approved
# 18           700    Approved
# 19           790    Approved

# %%
label_encoder = LabelEncoder()
df['loan_status'] = label_encoder.fit_transform(df['loan_status'])

# %%
df['loan_status'] #so here i changed approved to 0 and denied to 1
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     0
#      ..
# 56    0
# 57    1
# 58    0
# 59    0
# 60    0
# Name: loan_status, Length: 61, dtype: int64

# %%
x  = df[['age','income','credit_score']]
y = df['loan_status']

# %%
x_test,x_train,y_test,y_train = train_test_split(x,y)

# %%
y_test.shape
# Out:
# (45,)

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.98

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plot_tree(clf, filled=True, feature_names=['age','income','credit_score'], class_names=['No', 'Yes'])
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

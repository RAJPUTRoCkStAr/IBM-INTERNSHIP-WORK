# %%
import pandas as pd
a = pd.read_csv('foot.csv')

# %%
a.head()
# Out:
#                                                 name  \
# 0  Women's Casual Sports Shoes, Fashionable Versa...
# 1  2024 New Spring/Autumn Women Breathable Mesh H...
# 2  Women's Casual Slip-on Flat Skate Shoes With A...
# 3  Women Mesh Breathable Casual Shoes, Soft Non-S...
# 4                Women's Fashionable Casual Sneakers
#
#                                                 link  price_usd  \
# 0  https://us.shein.com/Women-s-Casual-Sports-Sho...      19.40
# 1  https://us.shein.com/2024-New-Spring-Autumn-Wo...      14.90
# 2  https://us.shein.com/Women-s-Casual-Slip-on-Fl...       7.50
# 3  https://us.shein.com/Women-Mesh-Breathable-Cas...      12.06
# 4  https://us.shein.com/Women-s-Fashionable-Casua...      13.53
#
#    mark_price_usd  star_rating  colour      seller_name review_count  \
# 0           24.40         4.83   Khaki     Womens Shoes           77
# 1           18.80         0.00     NaN  Limeiya Factory            0
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899 entries, 0 to 898
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            899 non-null    object
#  1   link            899 non-null    object
#  2   price_usd       899 non-null    float64
#  3   mark_price_usd  899 non-null    float64
#  4   star_rating     899 non-null    float64
#  5   colour          690 non-null    object
#  6   seller_name     9 non-null      object
#  7   review_count    899 non-null    object
#  8   sku_id          899 non-null    object
#  9   hero_image      899 non-null    object
# dtypes: float64(3), object(7)
# memory usage: 70.4+ KB

# %%
a.describe()
# Out:
#         price_usd  mark_price_usd  star_rating
# count  899.000000      899.000000   899.000000
# mean    17.303537       23.231624     0.043437
# std     15.234275       18.266408     0.458675
# min      0.610000        2.100000     0.000000
# 25%     11.900000       16.200000     0.000000
# 50%     15.800000       21.000000     0.000000
# 75%     19.990000       26.000000     0.000000
# max    247.500000      319.070000     4.920000

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
y = ['Ranjit', 'Mukesh', 'Ajith', 'Ajay']
x = [89,86,82,88]

# %%
plt.plot(x,y)

# %%
x = a['seller_name']
y= a['review_count']

# %%
plt.plot(x, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.plot(x, y)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
# ...

# %%
a = pd.read_csv('c.csv')

# %%
a.head()
# Out:
#      Name  Marks
# 0   Madan     87
# 1    Ajay     85
# 2   Ajith     89
# 3  Shivam     89
# 4     Raj     86

# %%
x = a['Name']
y = a['Marks']

# %%
plt.plot(x,y, '#05a4b3',lw=3)
plt.ylabel('Marks')
plt.xlabel('Name')
plt.title('ADIT Class',{'color':'red', 'size':15, 'family':'serif'})
# plt.grid(axis='x', animated=True, color='green', linestyle='-.')
plt.grid(axis='both', animated=True, mouseover=True)

# %%
plt.figure(figsize=(12,3))
# plt.barh(x,y, color ='#A0d0c0', width =0.9)
plt.barh(x,y)

plt.ylabel('Marks')
plt.xlabel('Name')
plt.title('ADIT Class',{'color':'red', 'size':15, 'family':'serif'})
# plt.grid(axis='x', animated=True, color='green', linestyle='-.')
plt.grid(axis='both')

# %%
x = [20,30,35,15]

# %%
plt.pie(x, labels=['Madan','Ajay', 'Ajith','Virat'], colors=['cyan','magenta','pink','yellow'],radius=1,startangle=0,counterclock=False)#explode=[0,0,0.25,0]
# plt.legend()
# Out:
# ([<matplotlib.patches.Wedge at 0x1b5e536ef10>,
# ...
#  [Text(0.8899186877588753, -0.6465637858537406, 'Madan'),
#   Text(-0.64656382751384, -0.8899186574910392, 'Ajay'),
#   Text(-0.49938947630209474, 0.9801072140121813, 'Ajith'),
#   Text(0.9801072140121813, 0.4993894763020948, 'Virat')])

# %%
x
# Out:
# 0        Madan
# 1         Ajay
# 2        Ajith
# 3       Shivam
# 4          Raj
# 5        Virat
# 6        Vikas
# 7        Mantu
# 8     Himanshu
# 9       Vikram
# 10       Mohit
# Name: Name, dtype: object

# %%
y
# Out:
# 0     87
# 1     85
# 2     89
# 3     89
# 4     86
# 5     89
# 6     93
# 7     89
# 8     92
# 9     93
# 10    92
# Name: Marks, dtype: int64

# %%
plt.scatter(x,y)

# %%
df = pd.read_csv('s.csv')
df.head()
# Out:
#    x   y
# 0  1  59
# 1  3  95
# 2  2  91
# 3  1  64
# 4  1  85

# %%
x = df['x']
y = df ['y']

# %%
plt.scatter(y,x)

# %%
x=[2,2.5,2.3,2.3,2.9,2.8,2.7,2.6]
y=[56,59,76,67,65,68,67,65]

# %%
plt.scatter(x,y, color='m',marker='^', edgecolors='r') #color='yellow')

# %%
a = pd.read_csv('c.csv')

# %%
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b5e3dddc50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b5e3ddd490>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b5e3ddc390>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b5e3e060d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b5e3e07dd0>],
#  'means': []}

# %%
a.describe()
# Out:
#            Marks
# count  11.000000
# mean   89.454545
# std     2.769969
# min    85.000000
# 25%    88.000000
# 50%    89.000000
# 75%    92.000000
# max    93.000000

# %%
a = pd.read_csv('c.csv')

# %%
y = a['Marks']
y
# Out:
# 0     87
# 1     85
# 2     89
# 3     89
# 4     86
# 5     89
# 6     93
# 7     89
# 8     92
# 9     93
# 10    92
# Name: Marks, dtype: int64

# %%
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b5dd168290>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b5db6ed890>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b5db7242d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b5e047f390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b5e05f8350>],
#  'means': []}

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b5e061a610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b5e061bf10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b5e061b6d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b5e069ca50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b5e069f790>],
#  'means': []}

# %%
plt.boxplot([4,5,3,7,6,4,12], showcaps=False, meanline=False, showfliers=False) #showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b5e1a30150>,
# ...
#  'caps': [],
#  'boxes': [<matplotlib.lines.Line2D at 0x1b5e1a32f50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b5dff58f10>],
#  'fliers': [],
#  'means': []}

# %%
plt.violinplot([4,5,3,7,6,4,12], vert=False, showmeans=True, showmedians=True,quantiles=[0,1])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1b5e4bf90d0>],
#  'cmeans': <matplotlib.collections.LineCollection at 0x1b5e4cc5b10>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1b5e4cea850>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1b5e4ceb6d0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1b5e4cb9750>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x1b5e4d01750>,
#  'cquantiles': <matplotlib.collections.LineCollection at 0x1b5e4bd0cd0>}

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 =pd.read_csv('practice1.csv')
df1
# Out:
#   Product Name   Price  quantity sold  discount              email
# 0        Apple  150000             10         5    rohan@gmail.com
# 1           Mi   20000             15         6    gopal@gmail.com
# 2        Nokia   10000             25         7   ramesh@GMAIL.COM
# 3      samsung   50000             30         5  Ganesh@gmaiul.com
# 4        Redmi   25000             20         5    kunal@gmail.com
# 5      oneplus   30000             50        10    Shyam@gmail.com

# %%
df1['Price'] = df1['Price'].astype(int)
df1['quantity sold'] = df1['quantity sold'].astype(int)

# %%
df1['Total Revenue'] = df1['Price'] * df1['quantity sold']
df1
# Out:
#   Product Name   Price  quantity sold  discount              email  \
# 0        Apple  150000             10         5    rohan@gmail.com
# 1           Mi   20000             15         6    gopal@gmail.com
# 2        Nokia   10000             25         7   ramesh@GMAIL.COM
# 3      samsung   50000             30         5  Ganesh@gmaiul.com
# 4        Redmi   25000             20         5    kunal@gmail.com
# 5      oneplus   30000             50        10    Shyam@gmail.com
#
#    Total Revenue
# 0        1500000
# 1         300000
# 2         250000
# 3        1500000
# 4         500000
# 5        1500000

# %%
email_addresses = [
    "john.doe@example.com",
    "jane.smith@company.org",
    "alice.brown@domain.net",
    "bob.jones@service.co"
]

# %%
usernames = [email.split('@')[0] for email in email_addresses]

print(usernames)
# Out:
# ['john.doe', 'jane.smith', 'alice.brown', 'bob.jones']

# %%
df1 ['username'] = df1 ['email'].str.split('@').str[0]
df1
# Out:
#   Product Name   Price  quantity sold  discount              email  \
# 0        Apple  150000             10         5    rohan@gmail.com
# 1           Mi   20000             15         6    gopal@gmail.com
# 2        Nokia   10000             25         7   ramesh@GMAIL.COM
# 3      samsung   50000             30         5  Ganesh@gmaiul.com
# 4        Redmi   25000             20         5    kunal@gmail.com
# 5      oneplus   30000             50        10    Shyam@gmail.com
#
#    Total Revenue username
# 0        1500000    rohan
# 1         300000    gopal
# 2         250000   ramesh
# 3        1500000   Ganesh
# 4         500000    kunal
# 5        1500000    Shyam

# %%
df1['discount'] = df1['discount'].astype(int)
df1['discount_price of product'] = df1 ['Price'] * (1 - df1 ['discount'] / 100)

df1
# Out:
#   Product Name   Price  quantity sold  discount              email  \
# 0        Apple  150000             10         5    rohan@gmail.com
# 1           Mi   20000             15         6    gopal@gmail.com
# 2        Nokia   10000             25         7   ramesh@GMAIL.COM
# 3      samsung   50000             30         5  Ganesh@gmaiul.com
# 4        Redmi   25000             20         5    kunal@gmail.com
# 5      oneplus   30000             50        10    Shyam@gmail.com
#
#    Total Revenue username  discount_price of product
# 0        1500000    rohan                   142500.0
# 1         300000    gopal                    18800.0
# 2         250000   ramesh                     9300.0
# 3        1500000   Ganesh                    47500.0
# 4         500000    kunal                    23750.0
# 5        1500000    Shyam                    27000.0

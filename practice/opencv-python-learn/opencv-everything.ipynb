# %%
import cv2

print("Constants in cv2:")
constants = [attr for attr in dir(cv2) if attr.isupper()]
print(constants)
# Out:
# Constants in cv2:
# ...

# %%
import cv2

print("Events in cv2:")
events = [attr for attr in dir(cv2) if 'EVENT' in attr]
print(events)
# Out:
# Events in cv2:
# ['EVENT_FLAG_ALTKEY', 'EVENT_FLAG_CTRLKEY', 'EVENT_FLAG_LBUTTON', 'EVENT_FLAG_MBUTTON', 'EVENT_FLAG_RBUTTON', 'EVENT_FLAG_SHIFTKEY', 'EVENT_LBUTTONDBLCLK', 'EVENT_LBUTTONDOWN', 'EVENT_LBUTTONUP', 'EVENT_MBUTTONDBLCLK', 'EVENT_MBUTTONDOWN', 'EVENT_MBUTTONUP', 'EVENT_MOUSEHWHEEL', 'EVENT_MOUSEMOVE', 'EVENT_MOUSEWHEEL', 'EVENT_RBUTTONDBLCLK', 'EVENT_RBUTTONDOWN', 'EVENT_RBUTTONUP']

# %%
import cv2
import inspect

print("Image Processing Functions in cv2:")
image_processing_functions = [
    'imread', 'imwrite', 'resize', 'cvtColor', 'blur', 'GaussianBlur',
    'medianBlur', 'bilateralFilter', 'threshold', 'adaptiveThreshold', 'inRange',
    'erode', 'dilate', 'morphologyEx', 'pyrDown', 'pyrUp', 'Canny', 'Sobel', 'Laplacian'
]
for func in image_processing_functions:
    if hasattr(cv2, func):
        print(func)
# Out:
# Image Processing Functions in cv2:
# imread
# imwrite
# resize
# cvtColor
# blur
# GaussianBlur
# medianBlur
# bilateralFilter
# threshold
# adaptiveThreshold
# inRange
# erode
# dilate
# morphologyEx
# pyrDown
# pyrUp
# Canny
# Sobel
# Laplacian

# %%
import cv2

print("Video Processing Functions in cv2:")
video_processing_functions = [
    'VideoCapture', 'VideoWriter', 'findContours', 'drawContours',
    'backgroundSubtractorMOG2', 'backgroundSubtractorKNN', 'CamShift', 'meanShift'
]
for func in video_processing_functions:
    if hasattr(cv2, func):
        print(func)
# Out:
# Video Processing Functions in cv2:
# VideoCapture
# VideoWriter
# findContours
# drawContours
# CamShift
# meanShift

# %%
import cv2

print("Feature Detection and Description in cv2:")
feature_detection_classes = [
    'SIFT_create', 'SURF_create', 'ORB_create', 'BFMatcher', 'FlannBasedMatcher',
    'SimpleBlobDetector_create', 'FastFeatureDetector_create', 'GFTTDetector_create'
]
for cls in feature_detection_classes:
    if hasattr(cv2, cls):
        print(cls)
# Out:
# Feature Detection and Description in cv2:
# SIFT_create
# ORB_create
# BFMatcher
# FlannBasedMatcher
# SimpleBlobDetector_create
# FastFeatureDetector_create
# GFTTDetector_create

# %%
import cv2

print("Geometric Transformations in cv2:")
geometric_transform_functions = [
    'warpAffine', 'warpPerspective', 'getAffineTransform', 'getPerspectiveTransform',
    'resize', 'rotate', 'getRotationMatrix2D', 'remap', 'flip', 'transpose'
]
for func in geometric_transform_functions:
    if hasattr(cv2, func):
        print(func)
# Out:
# Geometric Transformations in cv2:
# warpAffine
# warpPerspective
# getAffineTransform
# getPerspectiveTransform
# resize
# rotate
# getRotationMatrix2D
# remap
# flip
# transpose

# %%
import cv2

print("Camera Calibration and 3D Reconstruction in cv2:")
camera_calibration_functions = [
    'calibrateCamera', 'stereoCalibrate', 'stereoRectify', 'stereoBM_create',
    'stereoSGBM_create', 'reprojectImageTo3D', 'solvePnP', 'Rodrigues'
]
for func in camera_calibration_functions:
    if hasattr(cv2, func):
        print(func)
# Out:
# Camera Calibration and 3D Reconstruction in cv2:
# calibrateCamera
# stereoCalibrate
# stereoRectify
# reprojectImageTo3D
# solvePnP
# Rodrigues

# %%
import cv2

print("Machine Learning in cv2:")
machine_learning_classes = [
    'ml', 'dnn', 'face', 'text', 'bgsegm', 'bioinspired', 'xfeatures2d'
]
for ml_class in machine_learning_classes:
    if hasattr(cv2, ml_class):
        print(ml_class)
# Out:
# Machine Learning in cv2:
# ml
# dnn

# %%
import cv2

print("Drawing and Annotation in cv2:")
drawing_functions = [
    'line', 'rectangle', 'circle', 'ellipse', 'polylines', 'putText'
]
for func in drawing_functions:
    if hasattr(cv2, func):
        print(func)
# Out:
# Drawing and Annotation in cv2:
# line
# rectangle
# circle
# ellipse
# polylines
# putText

# %%
import cv2

print("Utilities in cv2:")
utility_functions = [
    'getTickCount', 'getTickFrequency', 'getOptimalDFTSize', 'setUseOptimized',
    'getUseOptimized', 'useOptimized', 'setNumThreads', 'getNumThreads', 'getBuildInformation',
    'getVersionString'
]
for func in utility_functions:
    if hasattr(cv2, func):
        print(func)
# Out:
# Utilities in cv2:
# getTickCount
# getTickFrequency
# getOptimalDFTSize
# setUseOptimized
# useOptimized
# setNumThreads
# getNumThreads
# getBuildInformation
# getVersionString

# %%
import cv2

print("All attributes in cv2:")
for attribute in dir(cv2):
    print(attribute)
# Out:
# All attributes in cv2:
# ACCESS_FAST
# ACCESS_MASK
# ACCESS_READ
# ACCESS_RW
# ACCESS_WRITE
# ADAPTIVE_THRESH_GAUSSIAN_C
# ADAPTIVE_THRESH_MEAN_C
# AGAST_FEATURE_DETECTOR_AGAST_5_8
# AGAST_FEATURE_DETECTOR_AGAST_7_12D
# AGAST_FEATURE_DETECTOR_AGAST_7_12S
# AGAST_FEATURE_DETECTOR_NONMAX_SUPPRESSION
# AGAST_FEATURE_DETECTOR_OAST_9_16
# AGAST_FEATURE_DETECTOR_THRESHOLD
# AKAZE
# AKAZE_DESCRIPTOR_KAZE
# AKAZE_DESCRIPTOR_KAZE_UPRIGHT
# AKAZE_DESCRIPTOR_MLDB
# AKAZE_DESCRIPTOR_MLDB_UPRIGHT
# AKAZE_create
# AffineFeature
# AffineFeature_create
# AgastFeatureDetector
# AgastFeatureDetector_AGAST_5_8
# AgastFeatureDetector_AGAST_7_12d
# AgastFeatureDetector_AGAST_7_12s
# AgastFeatureDetector_NONMAX_SUPPRESSION
# AgastFeatureDetector_OAST_9_16
# AgastFeatureDetector_THRESHOLD
# AgastFeatureDetector_create
# Algorithm
# AlignExposures
# AlignMTB
# AsyncArray
# BFMatcher
# BFMatcher_create
# BORDER_CONSTANT
# BORDER_DEFAULT
# BORDER_ISOLATED
# BORDER_REFLECT
# BORDER_REFLECT101
# ...

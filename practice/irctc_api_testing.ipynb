# %%
import requests

# %% [raw]
# search station

# %%
url = "https://irctc1.p.rapidapi.com/api/v1/searchStation"

querystring = {"query":"BSB"}

headers = {
	"x-rapidapi-key": "df3df38556mshaf705f750f27340p1e7b40jsncf340947eba6",
	"x-rapidapi-host": "irctc1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': True, 'message': 'Success', 'timestamp': 1719217365777, 'data': [{'name': 'BANARAS', 'eng_name': 'BANARAS', 'code': 'BSBS', 'state_name': 'Uttar Pradesh'}, {'name': 'BANSHLAI BRIDGE', 'eng_name': 'BANSHLAI BRIDGE', 'code': 'BSBR', 'state_name': 'WEST BENGAL'}, {'name': 'BHUSAWAL B CABIN', 'eng_name': 'BHUSAWAL B CABIN', 'code': 'BSBN', 'state_name': 'MAHARASHTRA'}, {'name': 'BIR SHIBPUR', 'eng_name': 'BIR SHIBPUR', 'code': 'BSBP', 'state_name': 'WEST BENGAL'}, {'name': 'VARANASI JN', 'eng_name': 'VARANASI JN', 'code': 'BSB', 'state_name': 'Uttar Pradesh'}, {'name': 'VARANASI JN', 'eng_name': 'VARANASI JN', 'code': 'BSBA', 'state_name': ''}, {'name': 'VARANASI OUTER CABIN', 'eng_name': 'VARANASI OUTER CABIN', 'code': 'XX-BSBC', 'state_name': 'UTTAR PRADESH'}, {'name': 'VARANASI YARD', 'eng_name': 'VARANASI YARD', 'code': 'BSBY', 'state_name': 'UTTAR PRADESH'}]}

# %% [raw]
# Search Train

# %%
url = "https://irctc1.p.rapidapi.com/api/v1/searchTrain"

querystring = {"query":"190"}

headers = {
	"x-rapidapi-key": "df3df38556mshaf705f750f27340p1e7b40jsncf340947eba6",
	"x-rapidapi-host": "irctc1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': True, 'message': 'Success', 'timestamp': 1719217428698, 'data': [{'train_number': '19037', 'train_name': 'AVADH EXP', 'eng_train_name': 'AVADH EXP', 'new_train_number': ''}, {'train_number': '19038', 'train_name': 'Avadh Express', 'eng_train_name': 'Avadh Express', 'new_train_number': ''}, {'train_number': '22948', 'train_name': 'BHAGALPUR - SURAT Tapti Ganga SF Exp', 'eng_train_name': 'BHAGALPUR - SURAT Tapti Ganga SF Exp', 'new_train_number': '19048'}, {'train_number': '22966', 'train_name': 'Bhagat Ki Kothi - Mumbai Bandra T SF Express', 'eng_train_name': 'Bhagat Ki Kothi - Mumbai Bandra T SF Express', 'new_train_number': '19066'}, {'train_number': '19013', 'train_name': 'BHUSAVAL - KATNI Express', 'eng_train_name': 'BHUSAVAL - KATNI Express', 'new_train_number': ''}, {'train_number': '19008', 'train_name': 'Bhusaval - Surat Express', 'eng_train_name': 'Bhusaval - Surat Express', 'new_train_number': ''}, {'train_number': '19006', 'train_name': 'Bhusaval - Surat Express'
# ...

# %%
Trainbetween station

# %%
url = "https://irctc1.p.rapidapi.com/api/v3/trainBetweenStations"

querystring = {"fromStationCode":"BVI","toStationCode":"NDLS","dateOfJourney":"2024-06-12"}

headers = {
	"x-rapidapi-key": "df3df38556mshaf705f750f27340p1e7b40jsncf340947eba6",
	"x-rapidapi-host": "irctc1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': True, 'message': 'Success', 'timestamp': 1719217528948, 'data': [{'train_number': '12951', 'train_name': 'Rajdhani Express', 'run_days': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], 'train_src': 'MMCT', 'train_dstn': 'NDLS', 'from_std': '17:24', 'from_sta': '17:22', 'local_train_from_sta': 1042, 'to_sta': '08:32', 'to_std': '08:32', 'from_day': 0, 'to_day': 1, 'd_day': 0, 'from': 'BVI', 'to': 'NDLS', 'from_station_name': 'BORIVALI', 'halt_stn': 5, 'distance': 1354, 'to_station_name': 'NEW DELHI', 'duration': '15:8', 'special_train': False, 'train_type': 'RAJ', 'score': 25, 'score_train_type': 5, 'score_booking_requency': 0, 'frequency_perc': 0, 'from_distance_text': '', 'to_distance_text': '', 'has_pantry': True, 'is_monsoon_timing_applicable': False, 'duration_rating': 1, 'score_duration': 10, 'score_std': 10, 'score_user_preferred': 0, 'train_date': '12-06-2024', 'class_type': ['3A', '2A', '1A']}, {'train_number': '12953', 'train_name': 'August Kranti Rajdhani Expr
# ...

# %% [raw]
# get train live station

# %%
url = "https://irctc1.p.rapidapi.com/api/v1/liveTrainStatus"

querystring = {"trainNo":"19038","startDay":"1"}

headers = {
	"x-rapidapi-key": "df3df38556mshaf705f750f27340p1e7b40jsncf340947eba6",
	"x-rapidapi-host": "irctc1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"status":true,"message":"Success","timestamp":1719217721915,"data":{"success":true,"user_id":0,"train_number":"19038","train_name":"Avadh Express","gps_unable":true,"train_start_date":"2024-06-23","notification_date":"2024-06-24","at_src_dstn":false,"at_src":false,"at_dstn":false,"is_run_day":true,"source":"BJU","destination":"BDTS","run_days":"MON,TUE,WED,THU,FRI,SAT,SUN","journey_time":2685,"std":"2024-06-23 07:20","data_from":"railyatri","new_alert_id":0,"new_alert_msg":"","diverted_stations":null,"instance_alert":0,"related_alert":0,"late_update":false,"is_ry_eta":true,"update_time":"2024-06-24 13:51:00 +0530","distance_from_source":1357,"total_distance":2256,"avg_speed":0,"si_no":214,"current_station_code":"KTSC","current_station_name":"KOTA JN SOUTH C.","status":"T","eta":"13:47","etd":"13:47","delay":84,"ahead_distance":6,"ahead_distance_text":"6 kms ahead","status_as_of":"As of 7 mins ago","platform_number":0,"cur_stn_sta":"12:23","cur_stn_std":"12:23","stoppage_number":0,"a
# ...

# %% [raw]
# get Train schedule

# %%
url = "https://irctc1.p.rapidapi.com/api/v1/getTrainSchedule"

querystring = {"trainNo":"12936"}

headers = {
	"x-rapidapi-key": "df3df38556mshaf705f750f27340p1e7b40jsncf340947eba6",
	"x-rapidapi-host": "irctc1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': True, 'message': 'Success', 'timestamp': 1719217782782, 'data': {'trainType': 'INTERCITY', 'trainNumber': '12936', 'trainName': 'InterCity Express', 'runDays': {'sun': True, 'mon': True, 'tue': True, 'wed': True, 'thu': True, 'fri': True, 'sat': True}, 'class': [{'value': '2S', 'name': 'Second Seating'}, {'value': 'CC', 'name': 'AC Chair Car'}], 'quota': [{'value': 'GN', 'name': 'QUOTA General'}, {'value': 'TQ', 'name': 'Tatkal'}, {'value': 'PT', 'name': 'Premium Tatkal'}, {'value': 'LD', 'name': 'Ladies'}, {'value': 'DF', 'name': 'Defence'}, {'value': 'FT', 'name': 'Foreign Tourist'}, {'value': 'DP', 'name': 'Duty Pass'}, {'value': 'HP', 'name': 'Handicapped'}, {'value': 'PH', 'name': 'Parliament House'}, {'value': 'SS', 'name': 'Lower Berth'}, {'value': 'YU', 'name': 'Yuva'}], 'route': [{'today_sta': 1000, 'sta': 1000, 'train_src': 'NVS', 'stop': True, 'std_min': 1002, 'station_name': 'NAVSARI', 'station_code': 'NVS', 'state_name': 'GUJARAT', 'state_code': 'GJ', 'sta_min
# ...

# %% [raw]
# get pnr status

# %%
url = "https://irctc1.p.rapidapi.com/api/v3/getPNRStatus"

querystring = {"pnrNumber":"dfgsdfgdfgdgf"}

headers = {
	"x-rapidapi-key": "df3df38556mshaf705f750f27340p1e7b40jsncf340947eba6",
	"x-rapidapi-host": "irctc1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())

# %% [raw]
# check seat avila

# %%
url = "https://irctc1.p.rapidapi.com/api/v1/checkSeatAvailability"

querystring = {"classType":"2A","fromStationCode":"ST","quota":"GN","toStationCode":"BVI","trainNo":"19038","date":"2024-06-21"}

headers = {
	"x-rapidapi-key": "df3df38556mshaf705f750f27340p1e7b40jsncf340947eba6",
	"x-rapidapi-host": "irctc1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': True, 'message': 'Success', 'timestamp': 1719217910678, 'data': [{'ticket_fare': 710, 'catering_charge': 0, 'alt_cnf_seat': False, 'total_fare': 710, 'date': '21-6-2024', 'confirm_probability_percent': '', 'confirm_probability': '', 'current_status': 'TRAIN DEPARTED'}, {'ticket_fare': 710, 'catering_charge': 0, 'alt_cnf_seat': False, 'total_fare': 710, 'date': '22-6-2024', 'confirm_probability_percent': '', 'confirm_probability': '', 'current_status': 'TRAIN DEPARTED'}, {'ticket_fare': 710, 'catering_charge': 0, 'alt_cnf_seat': False, 'total_fare': 710, 'date': '23-6-2024', 'confirm_probability_percent': '', 'confirm_probability': '', 'current_status': 'TRAIN DEPARTED'}, {'ticket_fare': 710, 'catering_charge': 0, 'alt_cnf_seat': False, 'total_fare': 710, 'date': '24-6-2024', 'confirm_probability_percent': '', 'confirm_probability': '', 'current_status': 'NOT AVAILABLE'}, {'ticket_fare': 710, 'catering_charge': 0, 'alt_cnf_seat': False, 'total_fare': 710, 'date': '25-6-2024
# ...

# %%
get train class

# %%
url = "https://irctc1.p.rapidapi.com/api/v1/getTrainClasses"

querystring = {"trainNo":"19038"}

headers = {
	"x-rapidapi-key": "df3df38556mshaf705f750f27340p1e7b40jsncf340947eba6",
	"x-rapidapi-host": "irctc1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': True, 'message': 'Success', 'timestamp': 1719217943779, 'data': ['SL', '3A', '2A', '2S', '1A', '3E']}

# %%
get fare detail of train

# %%
url = "https://irctc1.p.rapidapi.com/api/v2/getFare"

querystring = {"trainNo":"19038","fromStationCode":"ST","toStationCode":"BVI"}

headers = {
	"x-rapidapi-key": "df3df38556mshaf705f750f27340p1e7b40jsncf340947eba6",
	"x-rapidapi-host": "irctc1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': True, 'message': 'Success', 'timestamp': 1719217971058, 'data': {'general': [{'classType': '1A', 'fare': 1175, 'breakup': [{'title': 'Base Charges', 'key': 'baseFare', 'cost': 1059}, {'title': 'Reservation Charges', 'key': 'reservationCharges', 'cost': 60}, {'title': 'GST', 'key': 'serviceTax', 'cost': 56}, {'title': 'Total Amount', 'key': 'total', 'cost': 1175}]}, {'classType': '2A', 'fare': 710, 'breakup': [{'title': 'Base Charges', 'key': 'baseFare', 'cost': 626}, {'title': 'Reservation Charges', 'key': 'reservationCharges', 'cost': 50}, {'title': 'GST', 'key': 'serviceTax', 'cost': 34}, {'title': 'Total Amount', 'key': 'total', 'cost': 710}]}, {'classType': 'SL', 'fare': 175, 'breakup': [{'title': 'Base Charges', 'key': 'baseFare', 'cost': 155}, {'title': 'Reservation Charges', 'key': 'reservationCharges', 'cost': 20}, {'title': 'Total Amount', 'key': 'total', 'cost': 175}]}, {'classType': 'GN', 'fare': 90, 'breakup': [{'title': 'Base Charges', 'key': 'baseFare', 'cost
# ...

# %% [raw]
# get train by station

# %%
url = "https://irctc1.p.rapidapi.com/api/v3/getTrainsByStation"

querystring = {"stationCode":"BSB"}

headers = {
	"x-rapidapi-key": "df3df38556mshaf705f750f27340p1e7b40jsncf340947eba6",
	"x-rapidapi-host": "irctc1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': True, 'timestamp': 1719218028756, 'data': {'originating': [], 'passing': [], 'destination': []}}

# %% [raw]
# get live station

# %%
url = "https://irctc1.p.rapidapi.com/api/v3/getLiveStation"

querystring = {"fromStationCode":"bsb","toStationCode":"ddu","hours":"1"}

headers = {
	"x-rapidapi-key": "df3df38556mshaf705f750f27340p1e7b40jsncf340947eba6",
	"x-rapidapi-host": "irctc1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': True, 'timestamp': 1719218091736, 'data': [{'trainType': 'MAIL EXPRESS', 'trainNumber': '13238', 'trainName': 'KOTA - PATNA Express', 'runDays': {'sun': True, 'mon': False, 'tue': False, 'wed': False, 'thu': True, 'fri': True, 'sat': False}, 'arrivalTime': '38:35', 'departureTime': '38:45', 'classes': [{'value': 'SL', 'name': 'CLASS - Sleeper'}, {'value': '3A', 'name': 'Third AC'}, {'value': '2A', 'name': 'Second AC'}, {'value': '1A', 'name': 'First AC'}, {'value': '3E', 'name': '3 AC Economy'}]}, {'trainType': 'MAIN LINE ELECTRICAL MULTIPLE UNIT', 'trainNumber': '03289', 'trainName': 'VARANASI - PATNA MEMU Express Special (UnReserved)', 'runDays': {'sun': True, 'mon': True, 'tue': True, 'wed': True, 'thu': True, 'fri': True, 'sat': True}, 'arrivalTime': '00:00', 'departureTime': '15:00', 'classes': [{'value': 'SL', 'name': 'CLASS - Sleeper'}]}]}
